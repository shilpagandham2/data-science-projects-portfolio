# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpagandham2/data-science-projects-portfolio/blob/main/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = pd.read_csv("SIGMIOD and RELU .csv")

# %%
import pandas as pd

data = pd.read_csv("SIGMIOD and RELU .csv")

print(data.head())
# Out:
#    study  sleep  result
# 0      8      6       1
# 1      2      4       0
# 2      6      7       1
# 3      1      3       0

# %%
X = data[["study", "sleep"]]   # inputs
y = data["result"]             # output

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(3, activation='relu', input_shape=(2,)))  # hidden layer
model.add(Dense(1, activation='sigmoid'))                 # output layer

model.compile(optimizer='adam', loss='binary_crossentropy')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step - loss: 1.7651
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.7577
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.7503
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7430
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.7356
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.7283
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.7211
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.7138
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.7066
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.6994

# %%
history = model.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.6922
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6851
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.6780
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.6709
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.6638
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6568
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6498
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.6428
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.6359
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.6290

# %%
import pandas as pd

new_data = pd.DataFrame([[8, 6]], columns=["study", "sleep"])

model.predict(new_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# array([[0.04866306]], dtype=float32)

# %%
import numpy as np

model.predict(np.array([[8, 6]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# array([[0.04866306]], dtype=float32)

# %%
pred = model.predict(new_data)

if pred[0][0] > 0.5:
    print("PASS ✅")
else:
    print("FAIL ❌")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# FAIL ❌
